# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshugoyal2582003/Aimarket/blob/main/recipes/Time_Series/Time_Series_Getting_Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Energy Demand Forecasting with Granite Timeseries (TTM)
#
# TinyTimeMixers (TTMs) are compact pre-trained models for Multivariate Time-Series Forecasting, open-sourced by IBM Research. With less than 1 Million parameters, TTM introduces the notion of the first-ever "tiny" pre-trained models for Time-Series Forecasting. TTM outperforms several popular benchmarks demanding billions of parameters in zero-shot and few-shot forecasting and can easily be fine-tuned for multi-variate forecasts.

# %% [markdown]
# ### Install the TSFM Library
#
# The [granite-tsfm library](https://github.com/ibm-granite/granite-tsfm) provides utilities for working with Time Series Foundation Models (TSFM). Here the pinned version is retrieved and installed.

# %%
# Install the tsfm library
! pip install "granite-tsfm[notebooks]==0.3.3" "pandas<3"
# Out:
# Requirement already satisfied: granite-tsfm==0.3.3 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]==0.3.3) (0.3.3)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.6.1)
# Collecting transformers==4.56.0 (from transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3)
#   Using cached transformers-4.56.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (4.0.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.12/dist-packages (from granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.3.1)
# Requirement already satisfied: urllib3>=1.26.19 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (2.5.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (2.0.2)
# Requirement already satisfied: torch<2.9 in /usr/local/lib/python3.12/dist-packages (from granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (2.5.1)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]==0.3.3) (1.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]==0.3.3) (3.10.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]==0.3.3) (7.7.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]==0.3.3) (5.24.1)
# Requirement already satisfied: kaleido in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]==0.3.3) (1.3.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from granite-tsfm[notebooks]==0.3.3) (2.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (3.29.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (0.36.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (2.32.4)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (0.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (4.67.3)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3) (1.17.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch<2.9->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.3.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (3.7.1)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (0.70.16)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (2.2.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]==0.3.3) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]==0.3.3) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]==0.3.3) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]==0.3.3) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]==0.3.3) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->granite-tsfm[notebooks]==0.3.3) (3.0.16)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter->granite-tsfm[notebooks]==0.3.3) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter->granite-tsfm[notebooks]==0.3.3) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from jupyter->granite-tsfm[notebooks]==0.3.3) (7.17.1)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.12/dist-packages (from jupyter->granite-tsfm[notebooks]==0.3.3) (4.6.1)
# Requirement already satisfied: choreographer>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from kaleido->granite-tsfm[notebooks]==0.3.3) (1.3.0)
# Requirement already satisfied: logistro>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from kaleido->granite-tsfm[notebooks]==0.3.3) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.12/dist-packages (from kaleido->granite-tsfm[notebooks]==0.3.3) (3.11.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]==0.3.3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]==0.3.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]==0.3.3) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]==0.3.3) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]==0.3.3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->granite-tsfm[notebooks]==0.3.3) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->granite-tsfm[notebooks]==0.3.3) (9.1.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]==0.3.3) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]==0.3.3) (1.81.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]==0.3.3) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]==0.3.3) (5.29.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]==0.3.3) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->granite-tsfm[notebooks]==0.3.3) (3.1.8)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.26.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (5.9.5)
# Requirement already satisfied: platformdirs>=4.3.6 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.3.0->kaleido->granite-tsfm[notebooks]==0.3.3) (4.10.0)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.3.0->kaleido->granite-tsfm[notebooks]==0.3.3) (4.1.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (3.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.5.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->granite-tsfm[notebooks]==0.3.3) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->granite-tsfm[notebooks]==0.3.3) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->granite-tsfm[notebooks]==0.3.3) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->granite-tsfm[notebooks]==0.3.3) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->granite-tsfm[notebooks]==0.3.3) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->granite-tsfm[notebooks]==0.3.3) (6.5.7)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->granite-tsfm[notebooks]==0.3.3) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->granite-tsfm[notebooks]==0.3.3) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->granite-tsfm[notebooks]==0.3.3) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->granite-tsfm[notebooks]==0.3.3) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->granite-tsfm[notebooks]==0.3.3) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->granite-tsfm[notebooks]==0.3.3) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->granite-tsfm[notebooks]==0.3.3) (4.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.56.0->transformers[torch]==4.56.0->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (2026.6.17)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->granite-tsfm[notebooks]==0.3.3) (3.0.3)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (25.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (5.9.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (5.10.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (0.25.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (1.3.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]==0.3.3) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->granite-tsfm[notebooks]==0.3.3) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]==0.3.3) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]==0.3.3) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]==0.3.3) (3.3.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]==0.3.3) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter->granite-tsfm[notebooks]==0.3.3) (1.5.1)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (0.28.1)
# Requirement already satisfied: jupyter-builder>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (1.0.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (0.2.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->granite-tsfm==0.3.3->granite-tsfm[notebooks]==0.3.3) (1.24.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->granite-tsfm[notebooks]==0.3.3) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->granite-tsfm[notebooks]==0.3.3) (1.5.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (4.14.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->granite-tsfm[notebooks]==0.3.3) (0.8.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->granite-tsfm[notebooks]==0.3.3) (0.4)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (1.9.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (25.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (4.26.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->granite-tsfm[notebooks]==0.3.3) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->granite-tsfm[notebooks]==0.3.3) (0.8.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter->granite-tsfm[notebooks]==0.3.3) (2.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (2026.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (0.1.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->granite-tsfm[notebooks]==0.3.3) (3.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter->granite-tsfm[notebooks]==0.3.3) (1.4.0)
# Using cached transformers-4.56.0-py3-none-any.whl (11.6 MB)
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 73.2 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.46.3
#     Uninstalling transformers-4.46.3:
#       Successfully uninstalled transformers-4.46.3
# Successfully installed tokenizers-0.22.2 transformers-4.56.0

# %% [markdown]
# ### Import Packages
#
# From `tsfm_public`, we use the TinyTimeMixer model, forecasting pipeline, and plotting function.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import torch

from tsfm_public import (
    TimeSeriesForecastingPipeline,
    TinyTimeMixerForPrediction,
)
from tsfm_public.toolkit.visualization import plot_predictions

# %% [markdown]
# ### Download the data
#
# We'll work with a dataset of hourly electrical demand, generation by type, and weather in Spain. This dataset was originally available from Kaggle. To simplify access to the data, we will make use of the ([energy consumption](https://huggingface.co/datasets/vitaliy-sharandin/energy-consumption-hourly-spain) and [weather](https://huggingface.co/datasets/vitaliy-sharandin/energy-consumption-weather-hourly-spain)) datasets on Hugging Face.

# %%
DATA_FILE_PATH = "hf://datasets/vitaliy-sharandin/energy-consumption-hourly-spain/energy_dataset.csv"

# %% [markdown]
# ### Specify time and output variables
#
# We provide the names of the timestamp column and the target column to be predicted. The context length (in time steps) is set to match the pretrained model.

# %%
timestamp_column = "time"
target_columns = ["total load actual"]
context_length = 512

# %% [markdown]
# ### Read in the data
#
# We parse the csv into a pandas dataframe, filling in any null values, and create a single window containing `context_length` time points. We ensure the timestamp column is a datetime.

# %%
# Read in the data from the downloaded file.
input_df = pd.read_csv(
    DATA_FILE_PATH,
)
input_df[timestamp_column] = pd.to_datetime(input_df[timestamp_column], utc=True)

# Fill NA/NaN values by propagating the last valid value.
input_df = input_df.ffill()

# Only use the last `context_length` rows for prediction.
input_df = input_df.iloc[-context_length:,]

# Show the last few rows of the dataset.
input_df.tail()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#                            time  generation biomass  \
# 35059 2018-12-31 18:00:00+00:00               297.0
# 35060 2018-12-31 19:00:00+00:00               296.0
# 35061 2018-12-31 20:00:00+00:00               292.0
# 35062 2018-12-31 21:00:00+00:00               293.0
# 35063 2018-12-31 22:00:00+00:00               290.0
#
#        generation fossil brown coal/lignite  \
# 35059                                   0.0
# 35060                                   0.0
# 35061                                   0.0
# 35062                                   0.0
# 35063                                   0.0
#
#        generation fossil coal-derived gas  generation fossil gas  \
# 35059                                 0.0                 7634.0
# 35060                                 0.0                 7241.0
# 35061                                 0.0                 7025.0
# 35062                                 0.0                 6562.0
# 35063                                 0.0                 6926.0
#
#        generation fossil hard coal  generation fossil oil  \
# 35059                       2628.0                  178.0
# 35060                       2566.0                  174.0
# 35061                       2422.0                  168.0
# 35062                       2293.0                  163.0
# 35063                       2166.0                  163.0
#
#        generation fossil oil shale  generation fossil peat  \
# 35059                          0.0                     0.0
# 35060                          0.0                     0.0
# 35061                          0.0                     0.0
# 35062                          0.0                     0.0
# 35063                          0.0                     0.0
#
#        generation geothermal  ...  generation waste  generation wind offshore  \
# 35059                    0.0  ...             277.0                       0.0
# 35060                    0.0  ...             280.0                       0.0
# 35061                    0.0  ...             286.0                       0.0
# 35062                    0.0  ...             287.0                       0.0
# 35063                    0.0  ...             287.0                       0.0
#
#        generation wind onshore  forecast solar day ahead  \
# 35059                   3113.0                      96.0
# 35060                   3288.0                      51.0
# 35061                   3503.0                      36.0
# 35062                   3586.0                      29.0
# 35063                   3651.0                      26.0
#
#        forecast wind offshore eday ahead  forecast wind onshore day ahead  \
# 35059                                NaN                           3253.0
# 35060                                NaN                           3353.0
# 35061                                NaN                           3404.0
# 35062                                NaN                           3273.0
# 35063                                NaN                           3117.0
#
#        total load forecast  total load actual  price day ahead  price actual
# 35059              30619.0            30653.0            68.85         77.02
# 35060              29932.0            29735.0            68.40         76.16
# 35061              27903.0            28071.0            66.88         74.30
# 35062              25450.0            25801.0            63.93         69.89
# 35063              24424.0            24455.0            64.27         69.88
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Plot the target series
#
# Here we inspect a preview of the target time series column.

# %%
fig, axs = plt.subplots(len(target_columns), 1, figsize=(10, 2 * len(target_columns)), squeeze=False)
for ax, target_column in zip(axs, target_columns):
    ax[0].plot(input_df[timestamp_column], input_df[target_column])

# %% [markdown]
# ### Set up zero shot model
# The TTM model is hosted on [Hugging Face](https://huggingface.co/ibm-granite/granite-timeseries-ttm-v1), and is retrieved by the wrapper, `TinyTimeMixerForPrediction`. We have one input channel in this example.

# %%
# Instantiate the model.
zeroshot_model = TinyTimeMixerForPrediction.from_pretrained(
    "ibm-granite/granite-timeseries-ttm-r2",  # Name of the model on Hugging Face
    num_input_channels=len(target_columns),  # tsp.num_input_channels
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.24M [00:00<?, ?B/s]

# %% [markdown]
# ### Create a forecasting pipeline
#
# Set up the forecasting pipeline with the model, setting `frequency` given our knowledge of the sample frequency. In this example we set `explode_forecasts` to `False`, which keeps each sequence of predictions in a list within the dataframe cells. We then make a forecast on the dataset.

# %%
# Create a pipeline.
device = "cuda" if torch.cuda.is_available() else ("mps" if torch.mps.is_available() else "cpu")

pipeline = TimeSeriesForecastingPipeline(
    zeroshot_model,
    timestamp_column=timestamp_column,
    id_columns=[],
    target_columns=target_columns,
    explode_forecasts=False,
    freq="h",
    device=device,  # Specify your local GPU or CPU.
)

# Make a forecast on the target column given the input data.
zeroshot_forecast = pipeline(input_df)
zeroshot_forecast.tail()
# Out:
# Device set to use cpu
#                        time  \
# 0 2018-12-31 22:00:00+00:00
#
#                         total load actual_prediction  \
# 0  [23465.3671875, 22127.962890625, 21162.0644531...
#
#                                    total load actual
# 0  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...

# %% [markdown]
# ### Plot predictions along with the historical data.
#
# The predicted series picks up where the historical data ends, and we can see that it predicts a continuation of the cyclical pattern and an upward trend.

# %%
# Plot the historical data and predicted series.
plot_predictions(
    input_df=input_df,
    predictions_df=zeroshot_forecast,
    freq="h",
    timestamp_column=timestamp_column,
    channel=target_column,
    indices=[-1],
    num_plots=1,
)
